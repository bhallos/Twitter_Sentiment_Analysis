# %%
import numpy as np
import pandas as pd
import nltk
from nltk.corpus import stopwords
import re

# %%
df=pd.read_csv("Raw_Tweets_100.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0                                         Raw_Tweets
# 0           0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1           1  is upset that he can't update his Facebook by ...
# 2           2  @Kenichan I dived many times for the ball. Man...
# 3           3    my whole body feels itchy and like its on fire
# 4           4  @nationwideclass no, it's not behaving at all....
# 5           5                      @Kwesidei not the whole crew
# 6           6                 I am so happy I got my phone today
# 7           7  @LOLTrish hey  long time no see! Yes.. Rains a...
# 8           8               @Tatiana_K nope they didn't have it
# 9           9                          @twittera que me muera ?

# %%
stop_words=set(stopwords.words('english'))
stop_words.remove('not')

# %%
corpus=[]
for i in range(0,len(df)):
    review=re.sub('@\S+|https?:\S+|http?:\S|[^A-Za-z0-9]+',' ',df['Raw_Tweets'][i])
    review=review.lower()
    review=review.split()
    review=[word for word in review if not word in stop_words]
    review=' '.join(review)
    corpus.append(review)

# %%
df.Raw_Tweets=corpus

# %%
df.Raw_Tweets.head(10)
# Out:
# 0         awww bummer shoulda got david carr third day
# 1    upset update facebook texting might cry result...
# 2    dived many times ball managed save 50 rest go ...
# 3                     whole body feels itchy like fire
# 4                                 not behaving mad see
# 5                                       not whole crew
# 6                                happy got phone today
# 7    hey long time see yes rains bit bit lol fine t...
# 8                                                 nope
# 9                                            que muera
# Name: Raw_Tweets, dtype: object

# %%
#Importing textblob
from textblob import TextBlob

# %%
#Defining Textblob subjectivity and polarity functions.

def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# %%
#Create two new columns "Subjectivity" & "Polarity"
df['Tweet_Subjectivity'] = df["Raw_Tweets"].apply(getSubjectivity)
df['Tweet_Polarity'] = df["Raw_Tweets"].apply(getPolarity)

# %%
df.head(50)
# Out:
#     Unnamed: 0                                         Raw_Tweets  \
# 0            0       awww bummer shoulda got david carr third day
# 1            1  upset update facebook texting might cry result...
# 2            2  dived many times ball managed save 50 rest go ...
# 3            3                   whole body feels itchy like fire
# 4            4                               not behaving mad see
# 5            5                                     not whole crew
# 6            6                              happy got phone today
# 7            7  hey long time see yes rains bit bit lol fine t...
# 8            8                                               nope
# 9            9                                          que muera
# 10          10                    spring break plain city snowing
# 11          11          not comfortable watching movie last night
# 12          12            bear watch thought ua loss embarrassing
# ...

# %%
df.to_csv("Tweet_sentiments_score.csv")
